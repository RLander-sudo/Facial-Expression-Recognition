# %%
# ---------------------------------------------
# Streamlit Real-Time FER with Webcam
# ---------------------------------------------
import streamlit as st
from streamlit_webrtc import webrtc_streamer, VideoProcessorBase, WebRtcMode
import av
import cv2
import numpy as np
import tensorflow as tf
import pickle

st.set_page_config(page_title="Real-Time Facial Expression Recognition", layout="centered")

# Load model and class names
@st.cache_resource
def load_model():
    model = tf.keras.models.load_model("models/expression_model_20250509-093652.h5")
    with open("data/class_names.pkl", "rb") as f:
        class_names = pickle.load(f)
    return model, class_names

model, class_names = load_model()
IMG_SIZE = 48

# Define Video Processor
class EmotionProcessor(VideoProcessorBase):
    def __init__(self):
        self.face_cascade = cv2.CascadeClassifier(
            cv2.data.haarcascades + "haarcascade_frontalface_default.xml"
        )

    def recv(self, frame: av.VideoFrame) -> av.VideoFrame:
        image = frame.to_ndarray(format="bgr24")
        gray = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)
        faces = self.face_cascade.detectMultiScale(gray, scaleFactor=1.3, minNeighbors=5)

        for (x, y, w, h) in faces:
            face = gray[y:y+h, x:x+w]
            face = cv2.resize(face, (IMG_SIZE, IMG_SIZE)) / 255.0
            face_input = np.expand_dims(face, axis=(0, -1))

            prediction = model.predict(face_input)
            emotion_idx = np.argmax(prediction)
            label = class_names[emotion_idx]
            confidence = np.max(prediction)

            label_text = f"{label} ({confidence*100:.1f}%)"
            cv2.rectangle(image, (x, y), (x+w, y+h), (0, 255, 0), 2)
            cv2.putText(image, label_text, (x, y-10),
                        cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 0), 2)

        return av.VideoFrame.from_ndarray(image, format="bgr24")

# Streamlit UI
st.title("🎥 Real-Time Facial Expression Recognition")

webrtc_streamer(
    key="emotion",
    mode=WebRtcMode.SENDRECV,
    video_processor_factory=EmotionProcessor,
    media_stream_constraints={"video": True, "audio": False},
    async_processing=True,
)
# Out:
# 2025-05-09 13:31:14.523 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-09 13:31:32.865 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-09 13:31:32.881 WARNING streamlit.runtime.scriptrunner_utils.script_run_context: Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-09 13:31:38.049
#   Warning: to view this Streamlit app on a browser, run it with the following
#   command:
#
#     streamlit run C:\Users\rohit\anaconda3\envs\myEnv\lib\site-packages\ipykernel_launcher.py [ARGUMENTS]
# 2025-05-09 13:31:38.049 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-09 13:31:38.065 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-09 13:31:38.681 Thread 'Thread-3': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-09 13:31:38.681 Thread 'Thread-3': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-09 13:31:40.125 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-09 13:31:40.128 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-09 13:31:40.131 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-09 13:31:40.136 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-09 13:31:40.139 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-09 13:31:40.148 Session state does not function when running a script without `streamlit run`
# 2025-05-09 13:31:40.153 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-09 13:31:40.159 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-09 13:31:40.178 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-09 13:31:40.188 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-09 13:31:40.231 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-09 13:31:40.238 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-09 13:31:40.245 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2025-05-09 13:31:40.248 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# ---------------------------------------------------------------------------
# NoSessionError                            Traceback (most recent call last)
# Cell In[1], line 57
#      54 # Streamlit UI
#      55 st.title("🎥 Real-Time Facial Expression Recognition")
# ---> 57 webrtc_streamer(
#      58     key="emotion",
#      59     mode=WebRtcMode.SENDRECV,
#      60     video_processor_factory=EmotionProcessor,
#      61     media_stream_constraints={"video": True, "audio": False},
#      62     async_processing=True,
#      63 )
#
# File ~\anaconda3\envs\myEnv\lib\site-packages\streamlit_webrtc\component.py:522, in webrtc_streamer(key, mode, rtc_configuration, media_stream_constraints, desired_playing_state, player_factory, in_recorder_factory, out_recorder_factory, video_frame_callback, audio_frame_callback, queued_video_frames_callback, queued_audio_frames_callback, on_video_ended, on_audio_ended, video_processor_factory, audio_processor_factory, async_processing, video_receiver_size, audio_receiver_size, source_video_track, source_audio_track, sendback_video, sendback_audio, video_html_attrs, audio_html_attrs, translations, on_change, client_settings, video_transformer_factory, async_transform)
#     512     component_value = component_value_raw
#     514 # HACK: Save the component value in this run to the session state
#     515 # to be restored in the next run because the component values of
#     516 # component instances behind the one which calls `rerun()`
#    (...)
#     520 # the component value of the second instance will be None in the next run
#     521 # after `rerun()`.
# --> 522 session_info = get_this_session_info()
#     523 run_count = get_script_run_count(session_info) if session_info else None
#     524 if component_value is None:
#
# File ~\anaconda3\envs\myEnv\lib\site-packages\streamlit_webrtc\session_info.py:32, in get_this_session_info()
#      27 def get_this_session_info() -> Optional[SessionInfo]:
#      28     # The original implementation of SessionState (https://gist.github.com/tvst/036da038ab3e999a64497f42de966a92) has a problem    # noqa: E501
#      29     # as referred to in https://gist.github.com/tvst/036da038ab3e999a64497f42de966a92#gistcomment-3484515,                         # noqa: E501
#      30     # then fixed here.
#      31     # This code only works with streamlit>=0.65, https://gist.github.com/tvst/036da038ab3e999a64497f42de966a92#gistcomment-3418729 # noqa: E501
# ---> 32     session_id = get_session_id()
#      34     if VER_GTE_1_18_0:
#      35         from streamlit.runtime.runtime import Runtime
#
# File ~\anaconda3\envs\myEnv\lib\site-packages\streamlit_webrtc\session_info.py:22, in get_session_id()
#      20 ctx = get_script_run_ctx()
#      21 if ctx is None:
# ---> 22     raise NoSessionError("Failed to get the thread context")
#      24 return ctx.session_id
#
# NoSessionError: Failed to get the thread context
